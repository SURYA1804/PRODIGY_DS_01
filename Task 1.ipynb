# %%
#Import the Required Libraries

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("TASK_1_Metadata_Country.csv")

# %%
#Make copy of Dataset

# %%
data_1=data.copy()

# %%
data.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
data.isnull().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
#Removing the Unnamed column in data set

# %%
data.drop("Unnamed: 5",axis=1,inplace=True)

# %%
#Dropning the null value that present in IncomeGroup Column Alone

# %%
data.dropna(subset="IncomeGroup",inplace=True)

# %%
data.isna().sum()
# Out:
# Country Code      0
# Region            0
# IncomeGroup       0
# SpecialNotes    126
# TableName         0
# dtype: int64

# %%
#After Dropping the null value represent in IncomeGroup column

# %%
data.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 2          AFG                 South Asia           Low income
# 4          AGO         Sub-Saharan Africa  Lower middle income
# 5          ALB      Europe & Central Asia  Upper middle income
# 6          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName
# 0                                                NaN        Aruba
# 2  The reporting period for national accounts dat...  Afghanistan
# 4  The World Bank systematically assesses the app...       Angola
# 5                                                NaN      Albania
# 6                                                NaN      Andorra

# %%
#Plotting the IncomeGroup Column in histogram which represent the count

# %%
plt.hist(data["IncomeGroup"])
plt.show()

# %%
#Count plot of Data["IncomeGroup"]

# %%
sb.countplot(data["IncomeGroup"])
plt.show()

# %%
#In another dataset fill the null values with appropirate methods

# %%
data_1["IncomeGroup"].value_counts()
# Out:
# IncomeGroup
# High income            131
# Lower middle income     54
# Upper middle income     54
# Low income              26
# Name: count, dtype: int64

# %%
data_1["IncomeGroup"] = data_1["IncomeGroup"].fillna(data_1["IncomeGroup"].mode()[0])

# %%
data_1.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
#after filling the null values with mode value of column

# %%
plt.hist(data_1["IncomeGroup"])
plt.show()

# %%
#Barplot

# %%
sb.countplot(data_1["IncomeGroup"])
plt.show()

# %%
df=pd.read_excel("Population.xlsx")

# %%
df.drop([0],axis=0,inplace=True)

# %%
df.head()
# Out:
#      Year    Population Yearly %    Yearly  Migrants (net)  Median Age  \
# 1  2024.0  1.441720e+09   0.0092  13092189       -486784.0        28.6
# 2  2023.0  1.428628e+09   0.0081  11454490       -486136.0        28.2
# 3  2022.0  1.417173e+09   0.0068   9609331       -487303.0        27.9
# 4  2020.0  1.396387e+09   0.0096  13275077        -34772.0        27.3
# 5  2015.0  1.322867e+09   0.0129  16450577       -475094.0        25.5
#
#    Fertility Rate  Density (P/Km²)  Urban  Urban Population  \
# 1            1.98            485.0  0.368       530387142.0
# 2            2.00            481.0  0.363       518239122.0
# 3            2.01            477.0  0.357       506304869.0
# 4            2.05            470.0  0.346       483098640.0
# 5            2.29            445.0  0.324       429069459.0
#
#   Country's Share of  World Population India
# 1             0.1776      8.118836e+09     1
# 2             0.1776      8.045311e+09     1
# ...

# %%
sb.distplot(df["Density (P/Km²)"])
plt.show()
# Out:
# /tmp/ipykernel_3698/1644628989.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df["Density (P/Km²)"])

# %%
sb.distplot(df["Yearly"])
plt.show()
# Out:
# /tmp/ipykernel_3698/1166754192.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df["Yearly"])

# %%
plt.hist(df["Urban Population"],rwidth=0.5)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(x=df.Year,y=df.India)
plt.title("India Population In World")
plt.ylabel("Rank")
plt.show()
